# %% [markdown]
# # Scikit-Learn Linear Regression

# %%
from sklearn import datasets 
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
X, y = datasets.load_diabetes(return_X_y = True)

# %%
X.shape
# Out:
# (442, 10)

# %%
y.shape
# Out:
# (442,)

# %%
plt.scatter(X[:,0], y)

# %%
plt.scatter(X[:, 1], y)

# %%
X_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
l_reg = linear_model.LinearRegression()
model = l_reg.fit(X_train, y_train)

# %%
prediction = model.predict(x_test)

# %%
prediction
# Out:
# array([ 86.5191477 , 113.18968065, 156.31823238,  99.41855023,
#        260.32807766,  50.43891324, 196.62358847,  88.3151303 ,
#         76.89656829, 160.76092783, 208.63849359, 123.30668567,
#        131.48923873, 230.9888033 , 140.10216924, 159.31051317,
#         92.06505113, 280.21978538,  98.92819019, 138.50616083,
#        182.12668512, 206.1920619 , 137.19345482, 158.34389769,
#        152.14315487, 176.08610011, 150.39012436, 239.43463636,
#        209.86840137, 175.55872357, 212.32052098, 152.60757729,
#        225.66377828, 157.23983505, 111.90845601, 208.74837256,
#        219.51016838, 189.52062777,  74.55993724, 166.49207892,
#        163.20101962, 142.08569564, 256.21248408,  76.35281116,
#         97.87232405,  52.78781686,  82.88772114, 212.32049631,
#        107.39759781, 218.51818435, 200.44253845, 166.54158979,
#         67.82763807, 158.01511951, 250.9076713 , 109.9211696 ,
#        245.22225136, 292.09577144, 153.73341623, 133.06074923,
#        234.80394506, 236.97007489, 232.07916749, 123.47011568,
#         74.92352129,  83.6127129 , 122.45576309, 140.63635868,
#        162.62378822, 121.68537363, 273.98609191, 148.24557772,
#        192.08505282, 159.12876914, 234.72868937, 157.13985569,
#        134.14314784, 149.94666632,  98.27436186, 142.94149071,
#        201.92504537, 138.43455479,  81.71244723, 180.68032658,
#        251.69293201, 122.0834365 ,  69.69531443, 258.67428519,
#        122.4298142 ])

# %%
plt.scatter(prediction, y_test)

# %%
print("Accuracy/ R^2", l_reg.score(X, y))
# Out:
# Accuracy/ R^2 0.5150637140333916

# %%
print("Regression coefficients: ", l_reg.coef_)
# Out:
# Regression coefficients:  [   3.67028677 -274.83758878  484.52011932  365.38775734 -805.59316844
#   449.26966484  124.22369267  258.37238552  797.82642095   18.67409991]

# %%
print("y_intercept", l_reg.intercept_)
# Out:
# y_intercept 152.621912323935
