# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Kshitij\OneDrive\Documents\Python Libraries\Scikit-Learn\Decision_Tree_Drugs_Dataset.csv')

# %%
df
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  drugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  drugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.isna().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, BP, Cholesterol, Na_to_K, Drug]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
x = df.Sex.value_counts()
print(x)
p = sns.countplot(data = df, x = "Sex")
plt.show()
# Out:
# M    104
# F     96
# Name: Sex, dtype: int64

# %%
x = df.Drug.value_counts()
print(x)
p = sns.countplot(data = df, x = "Drug")
plt.show()
# Out:
# drugY    91
# drugX    54
# drugA    23
# drugC    16
# drugB    16
# Name: Drug, dtype: int64

# %%
df['Drug'].unique()
# Out:
# array(['drugY', 'drugC', 'drugX', 'drugA', 'drugB'], dtype=object)

# %%
plt.figure(figsize = (10,10))
sns.distplot(df[df['Drug'] == 'drugY']['Age'], color = 'green',)
sns.distplot(df[df['Drug'] == 'drugX']['Age'], color = 'red',)
sns.distplot(df[df['Drug'] == 'drugA']['Age'], color = 'black',)
sns.distplot(df[df['Drug'] == 'drugB']['Age'], color = 'orange',)
sns.distplot(df[df['Drug'] == 'drugC']['Age'], color = 'blue',)
plt.title("Age Vs Drug Class")
plt.show()
# Out:
# C:\Users\Kshitij\AppData\Local\Temp\ipykernel_21084\2103000543.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Drug'] == 'drugY']['Age'], color = 'green',)
# C:\Users\Kshitij\AppData\Local\Temp\ipykernel_21084\2103000543.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Drug'] == 'drugX']['Age'], color = 'red',)
# C:\Users\Kshitij\AppData\Local\Temp\ipykernel_21084\2103000543.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Drug'] == 'drugA']['Age'], color = 'black',)
# C:\Users\Kshitij\AppData\Local\Temp\ipykernel_21084\2103000543.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Drug'] == 'drugB']['Age'], color = 'orange',)
# C:\Users\Kshitij\AppData\Local\Temp\ipykernel_21084\2103000543.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Drug'] == 'drugC']['Age'], color = 'blue',)

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()

# %%
df['BP'] =  oe.fit_transform(df[['BP']])
df['Sex'] =  oe.fit_transform(df[['Sex']])
df['Cholesterol'] =  oe.fit_transform(df[['Cholesterol']])
df['Drug'] =  oe.fit_transform(df[['Drug']])

# %%
df
# Out:
#      Age  Sex   BP  Cholesterol  Na_to_K  Drug
# 0     23  0.0  0.0          0.0   25.355   4.0
# 1     47  1.0  1.0          0.0   13.093   2.0
# 2     47  1.0  1.0          0.0   10.114   2.0
# 3     28  0.0  2.0          0.0    7.798   3.0
# 4     61  0.0  1.0          0.0   18.043   4.0
# ..   ...  ...  ...          ...      ...   ...
# 195   56  0.0  1.0          0.0   11.567   2.0
# 196   16  1.0  1.0          0.0   12.006   2.0
# 197   52  1.0  2.0          0.0    9.894   3.0
# 198   23  1.0  2.0          1.0   14.020   3.0
# 199   40  0.0  1.0          1.0   11.349   3.0
#
# [200 rows x 6 columns]

# %%
X = df.iloc[:, 0:-1]
y = df.iloc[:,-1]

# %%
X
# Out:
#      Age  Sex   BP  Cholesterol  Na_to_K
# 0     23  0.0  0.0          0.0   25.355
# 1     47  1.0  1.0          0.0   13.093
# 2     47  1.0  1.0          0.0   10.114
# 3     28  0.0  2.0          0.0    7.798
# 4     61  0.0  1.0          0.0   18.043
# ..   ...  ...  ...          ...      ...
# 195   56  0.0  1.0          0.0   11.567
# 196   16  1.0  1.0          0.0   12.006
# 197   52  1.0  2.0          0.0    9.894
# 198   23  1.0  2.0          1.0   14.020
# 199   40  0.0  1.0          1.0   11.349
#
# [200 rows x 5 columns]

# %%
y
# Out:
# 0      4.0
# 1      2.0
# 2      2.0
# 3      3.0
# 4      4.0
#       ...
# 195    2.0
# 196    2.0
# 197    3.0
# 198    3.0
# 199    3.0
# Name: Drug, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, test_size = 0.2)

# %%
X_train
# Out:
#      Age  Sex   BP  Cholesterol  Na_to_K
# 79    32  0.0  1.0          1.0   10.840
# 197   52  1.0  2.0          0.0    9.894
# 38    39  0.0  2.0          1.0    9.709
# 24    33  0.0  1.0          0.0   33.486
# 122   34  1.0  2.0          0.0   22.456
# ..   ...  ...  ...          ...      ...
# 106   22  1.0  2.0          0.0   11.953
# 14    50  0.0  2.0          0.0   12.703
# 92    29  0.0  0.0          0.0   29.450
# 179   67  0.0  2.0          0.0   15.891
# 102   28  0.0  1.0          0.0   13.127
#
# [160 rows x 5 columns]

# %%
y_train
# Out:
# 79     3.0
# 197    3.0
# 38     3.0
# 24     4.0
# 122    4.0
#       ...
# 106    3.0
# 14     3.0
# 92     4.0
# 179    4.0
# 102    2.0
# Name: Drug, Length: 160, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier
clf_gini = DecisionTreeClassifier(criterion = 'gini', random_state = 0)
clf_gini.fit(X_train, y_train)
y_pred_gini = clf_gini.predict(X_test)

# %%
y_pred_gini
# Out:
# array([3., 4., 3., 2., 4., 4., 4., 3., 0., 3., 0., 3., 4., 0., 1., 4., 1.,
#        3., 2., 4., 1., 3., 3., 4., 4., 4., 2., 3., 4., 3., 4., 2., 2., 4.,
#        0., 4., 3., 0., 4., 0.])

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_pred_gini, y_test))
# Out:
# 1.0

# %%
from sklearn import tree
plt.figure(figsize = (10,10))
tree.plot_tree(clf_gini.fit(X_train, y_train))
plt.show()

# %%
clf_entropy = DecisionTreeClassifier(criterion = 'entropy', max_depth = 3, random_state = 0)
clf_entropy.fit(X_train, y_train)
y_pred_entropy = clf_entropy.predict(X_test)
plt.show()

# %%
print(accuracy_score(y_test, y_pred_entropy))
plt.figure(figsize = (10,10))
tree.plot_tree(clf_entropy.fit(X_train, y_train))
plt.show()
# Out:
# 0.875
